# %% [markdown]
# ### Principal Component Analysis Examples
# Based on the Python Data Science Handbook by Jake VanderPlas

# %% [markdown]
# #### Standard imports

# %%
# %matplotlib inline
import numpy as np                 # for handling arrays
import matplotlib.pyplot as plt    # for plotting
import seaborn as sns; sns.set()   # Python visualization library based on matplotlib

# %% [markdown]
# #### Generating and plotting a two-dimensional dataset

# %%
rng = np.random.RandomState(1)
X = np.dot(rng.rand(2, 2), rng.randn(2, 200)).T
plt.scatter(X[:, 0], X[:, 1], s=10)                # plotting dataset with points of size 10
plt.axis('equal');
